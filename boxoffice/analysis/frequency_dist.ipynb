# %%
from boxoffice.db.frames import get_movie_frame, get_box_office_day_frame

movie_frame = get_movie_frame()

box_office_day_frame = get_box_office_day_frame()

# %%
sums = box_office_day_frame.groupby('movie')['revenue'].sum()

movie_frame['total_box_office'] = movie_frame['id'].map(sums)

movie_frame.head()
# Out:
#    id       truncated_title                           slug  \
# 0   1  Deadpool & Wolverine  Deadpool-and-Wolverine-(2024)
# 1   2              Twisters                Twisters-(2024)
# 2   3       Despicable Me 4         Despicable-Me-4-(2024)
# 3   4                  Trap                    Trap-(2024)
# 4   5          Inside Out 2            Inside-Out-2-(2024)
#
#                   title  release_year  \
# 0  Deadpool & Wolverine          2024
# 1              Twisters          2024
# 2       Despicable Me 4          2024
# 3                  Trap          2024
# 4          Inside Out 2          2024
#
#                                               poster  \
# 0  https://www.the-numbers.com/images/movies/opus...
# 1  https://www.the-numbers.com/images/movies/opus...
# 2  https://www.the-numbers.com/images/movies/opus...
# 3  https://www.the-numbers.com/images/movies/opus...
# 4  https://www.the-numbers.com/images/movies/opus...
#
#                                             synopsis mpaa_rating  \
# 0  A listless Wade Wilson toils away in civilian ...           R
# 1  Kate Cooper, a former storm chaser haunted by ...       PG-13
# 2  Gru, supervillain-turned-Anti-Villain League-a...          PG
# 3  A father and teen daughter attend a pop concer...       PG-13
# 4  The film follows newly minted teenager Riley j...          PG
#
#                                   mpaa_rating_reason mpaa_rating_date  \
# 0  strong bloody violence and language throughout...       2024-06-05
# 1  intense action and peril, some language and in...       2024-05-22
# 2                             action and rude humor.       2024-03-20
# 3    some violent content and brief strong language.       2024-07-10
# 4                            some thematic elements.       2024-05-15
#
#    running_time                        source              genre  \
# 0         127.0  Based on Comic/Graphic Novel             Action
# 1         122.0           Original Screenplay  Thriller/Suspense
# 2          94.0           Original Screenplay          Adventure
# 3          94.0           Original Screenplay  Thriller/Suspense
# 4         100.0           Original Screenplay          Adventure
#
#        production_method         creative_type       budget  total_box_office
# 0  Animation/Live Action            Super Hero  200000000.0         662889861
# 1            Live Action  Contemporary Fiction  155000000.0         277528015
# 2      Digital Animation          Kids Fiction  100000000.0         359844685
# 3            Live Action  Contemporary Fiction          NaN          44741544
# 4      Digital Animation          Kids Fiction  200000000.0         665731878

# %%
# frequency distribution of movies by total box office
movie_frame['total_box_office'].hist(bins=100)
# Out:
# <Axes: >
